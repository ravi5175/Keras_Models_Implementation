# %%
from google.colab import drive

# %%
drive.mount('/gdrive',force_remount=True)
# Out:
# Mounted at /gdrive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /gdrive/My Drive/test_image_description
# Out:
# /gdrive/.shortcut-targets-by-id/15EemvNwS0nRopPgioB0BWpY16J8ax-0v/test_image_description

# %%
# !cp -r '/gdrive/My Drive/test_image_description' '/gdrive/My Drive/Image Description'

# %%
# %cd /gdrive/My Drive/Image Description/test_image_description
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-28-8188d4fdfd30>", line 1, in <module>
#     get_ipython().magic('cd /gdrive/My Drive/Image Description/test_image_description')
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-91>", line 2, in cd
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
# ...

# %%
pwd
# Out:
# '/gdrive/.shortcut-targets-by-id/15EemvNwS0nRopPgioB0BWpY16J8ax-0v/test_image_description'

# %%
# !python test_generator.py -i "img1.jpg"
# Out:
# Using TensorFlow backend.
# 2020-07-02 06:14:56.412903: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Traceback (most recent call last):
#   File "test_generator.py", line 52, in <module>
#     model = load_model('models/model_29.h5')
#   File "/usr/local/lib/python3.6/dist-packages/keras/engine/saving.py", line 492, in load_wrapper
#     return load_function(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/keras/engine/saving.py", line 583, in load_model
#     with H5Dict(filepath, mode='r') as h5dict:
#   File "/usr/local/lib/python3.6/dist-packages/keras/utils/io_utils.py", line 191, in __init__
#     self.data = h5py.File(path, mode=mode)
#   File "/usr/local/lib/python3.6/dist-packages/h5py/_hl/files.py", line 408, in __init__
#     swmr=swmr)
#   File "/usr/local/lib/python3.6/dist-packages/h5py/_hl/files.py", line 173, in make_fid
#     fid = h5f.open(name, flags, fapl=fapl)
# ...

# %%
pwd
# Out:
# '/gdrive/.shortcut-targets-by-id/15EemvNwS0nRopPgioB0BWpY16J8ax-0v/test_image_description'
